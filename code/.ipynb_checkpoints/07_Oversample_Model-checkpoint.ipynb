# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay, confusion_matrix, classification_report, recall_score, precision_score, f1_score

from sklearn.linear_model import LogisticRegression

from imblearn.over_sampling import RandomOverSampler

# %%
df = pd.read_csv('../data/reviews_with_ratings_cleaned.csv', index_col = 'Unnamed: 0', keep_default_na = False)
df.sample(5)
# Out:
#                 listing_id                   id        date  reviewer_id  \
# 311787  841516880074550210   971746925863447005  2023-09-02    411590824
# 152872            22773755            489897607  2019-07-17     87268392
# 193525            32726582   552833473192770664  2022-02-01      5317044
# 263232            50397883   591323482263553694  2022-03-26     54668225
# 254223            48934429  1029731889295658617  2023-11-21    547093621
#
#        reviewer_name                                           comments  \
# 311787        LaToya  My stay was really good, the room was clean an...
# 152872        Stefan  Es war eine wirklich gute Unterkunft. Man ist ...
# 193525        Jasper  Great place. Very well located and in general ...
# 263232       Valeria  Joe was wonderful! Super helpful when we had t...
# 254223          Judy  Booking with Sohourn was super easy! Our host ...
#
#         avg_rating  avg_score_below_4  avg_score_below_5th_percentile  \
# 311787    4.838571                  0                               0
# 152872    4.868571                  0                               0
# 193525    4.921429                  0                               0
# 263232    4.912857                  0                               0
# 254223    4.888571                  0                               0
#
#                                            comments_clean
# 311787  my stay was really good the room was clean and...
# 152872  es war eine wirklich gute unterkunft man ist s...
# 193525  great place very well located and in general a...
# 263232  joe was wonderful super helpful when we had tr...
# 254223  booking with sohourn was super easy our host w...

# %%
df.isnull().sum()
# Out:
# listing_id                        0
# id                                0
# date                              0
# reviewer_id                       0
# reviewer_name                     0
# comments                          0
# avg_rating                        0
# avg_score_below_4                 0
# avg_score_below_5th_percentile    0
# comments_clean                    0
# dtype: int64

# %%
print(df['avg_score_below_5th_percentile'].value_counts()),
print('*'*30)
df['avg_score_below_5th_percentile'].value_counts(normalize = True)
# Out:
# avg_score_below_5th_percentile
# 0    320774
# 1      2033
# Name: count, dtype: int64
# ******************************
# avg_score_below_5th_percentile
# 0    0.993702
# 1    0.006298
# Name: proportion, dtype: float64

# %%
X = df[['comments_clean']] # Had to make it double square brackets to make it a 2D array
X.shape
# Out:
# (322807, 1)

# %%
y = df['avg_score_below_5th_percentile']
y.shape
# Out:
# (322807,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
X_train
# Out:
#                                            comments_clean
# 67125   our client michael stayed for one evening and ...
# 63788   just a wonderful experience all around locatio...
# 20242   this airbnb was beautiful it is really close t...
# 160237                                         great stay
# 247799             super easy check in and great location
# ...                                                   ...
# 178131  jen and john s place is perfect for both perso...
# 103396  ashley has done a great job of selling her pla...
# 150074  this is the nicest basement apt in dc we ve st...
# 304472  i booked a last minute trip to d c and was loo...
# 147754  i am a long term guest at stacy s he is a grea...
#
# [242105 rows x 1 columns]

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((242105, 1), (80702, 1), (242105,), (80702,))

# %% [markdown]
# #### Will random over sample the minority class

# %%
ros = RandomOverSampler()

# %%
X_train_over, y_train_over = ros.fit_resample(X_train, y_train)

# %%
X_train_over
# Out:
#                                            comments_clean
# 0       our client michael stayed for one evening and ...
# 1       just a wonderful experience all around locatio...
# 2       this airbnb was beautiful it is really close t...
# 3                                              great stay
# 4                  super easy check in and great location
# ...                                                   ...
# 481155  it s a very pretty very spacious apartment we ...
# 481156  the bedroom is as described clean and spacious...
# 481157  accessible to the new developed part of dc tra...
# 481158                       close to children s hospital
# 481159  lovely helpful host on a quiet street and shor...
#
# [481160 rows x 1 columns]

# %%
X_train_over.isnull().sum()
# Out:
# comments_clean    0
# dtype: int64

# %%
y_train_over
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 481155    1
# 481156    1
# 481157    1
# 481158    1
# 481159    1
# Name: avg_score_below_5th_percentile, Length: 481160, dtype: int64

# %%
X_train.shape, y_train.shape
# Out:
# ((242105, 1), (242105,))

# %%
X_train_over.shape, y_train_over.shape
# Out:
# ((481160, 1), (481160,))

# %% [markdown]
# #### The minority class (below 5th percentile) is now balanced with the majority class (above 5th percentile)

# %%
y_train.value_counts()
# Out:
# avg_score_below_5th_percentile
# 0    240580
# 1      1525
# Name: count, dtype: int64

# %%
y_train_over.value_counts()
# Out:
# avg_score_below_5th_percentile
# 0    240580
# 1    240580
# Name: count, dtype: int64

# %% [markdown]
# #### Will run a TFidfVectorizer first without a GridSearch

# %%
tf = TfidfVectorizer(stop_words = 'english')

# %%
X_train_over
# Out:
#                                            comments_clean
# 0       our client michael stayed for one evening and ...
# 1       just a wonderful experience all around locatio...
# 2       this airbnb was beautiful it is really close t...
# 3                                              great stay
# 4                  super easy check in and great location
# ...                                                   ...
# 481155  it s a very pretty very spacious apartment we ...
# 481156  the bedroom is as described clean and spacious...
# 481157  accessible to the new developed part of dc tra...
# 481158                       close to children s hospital
# 481159  lovely helpful host on a quiet street and shor...
#
# [481160 rows x 1 columns]

# %%
tf.fit(X_train_over['comments_clean'])
# Out:
# TfidfVectorizer(stop_words='english')

# %%
X_train_tf = tf.transform(X_train_over['comments_clean'])

# %%
X_train_tf
# Out:
# <481160x66850 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9342747 stored elements in Compressed Sparse Row format>

# %%
X_test_tf = tf.transform(X_test['comments_clean'])

# %%
X_test_tf
# Out:
# <80702x66850 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1574619 stored elements in Compressed Sparse Row format>

# %%
X_train_tf.shape, X_test_tf.shape
# Out:
# ((481160, 66850), (80702, 66850))

# %%
logr = LogisticRegression(class_weight = 'balanced')

# %%
logr.fit(X_train_tf, y_train_over)
# Out:
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced')

# %%
logr.predict(X_test_tf)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train_tf.shape, y_train_over.shape, X_test_tf.shape, y_test.shape
# Out:
# ((481160, 66850), (481160,), (80702, 66850), (80702,))

# %%
logr.score(X_train_tf, y_train_over), logr.score(X_test_tf, y_test)
# Out:
# (0.9134778452074154, 0.8826175311640356)

# %%
ConfusionMatrixDisplay.from_estimator(logr, X_test_tf, y_test);

# %% [markdown]
# #### Best recall score so far at 0.47.

# %%
recall_score(y_test, logr.predict(X_test_tf) )
# Out:
# 0.47244094488188976

# %%
precision_score(y_test, logr.predict(X_test_tf) )
# Out:
# 0.02541026998411858

# %% [markdown]
# #### But poor F1 score

# %%
f1_score(y_test, logr.predict(X_test_tf) )
# Out:
# 0.04822666532703707

# %%
logr_tf_df = pd.DataFrame(logr.predict_proba(X_test_tf), columns = ['above_5th_percentile', 'below_5th_percentile'] )
logr_tf_df
# Out:
#        above_5th_percentile  below_5th_percentile
# 0                  0.814711              0.185289
# 1                  0.997034              0.002966
# 2                  0.995417              0.004583
# 3                  0.992123              0.007877
# 4                  0.956327              0.043673
# ...                     ...                   ...
# 80697              0.990291              0.009709
# 80698              0.647365              0.352635
# 80699              0.924346              0.075654
# 80700              0.970296              0.029704
# 80701              0.722199              0.277801
#
# [80702 rows x 2 columns]

# %%
tf_logr_feature_names = pd.DataFrame(tf.get_feature_names_out(), columns = ['features'] )
tf_logr_feature_names
# Out:
#                         features
# 0                             00
# 1                            000
# 2                            001
# 3                            007
# 4                            00a
# ...                          ...
# 66845  １階のスペースを使ってくださいとフレキシブルでした
# 66846                  ２日間だけでしたが
# 66847         ２０分歩けば大きなスーパーがあります
# 66848                         ５分
# 66849                        ｔhe
#
# [66850 rows x 1 columns]

# %% [markdown]
# ##### Strange words showing up - some foreign languages, etc.

# %%
tf_logr_word_probs = tf_logr_feature_names.join(logr_tf_df)
tf_logr_word_probs.sort_values('below_5th_percentile', ascending = False).head(20)
# Out:
#                     features  above_5th_percentile  below_5th_percentile
# 50068                 toffee              0.000004              0.999996
# 30033                  looks              0.000046              0.999954
# 22625             gratuitous              0.000205              0.999795
# 6286              befürchten              0.000259              0.999741
# 64923                   신석하고              0.000399              0.999601
# 45788                  smoky              0.000549              0.999451
# 48162               supernal              0.000667              0.999333
# 45774           smithsonians              0.000699              0.999301
# 37468                    pie              0.000760              0.999240
# 42035            respondendo              0.000811              0.999189
# 55317                  xtras              0.000835              0.999165
# 60520  感谢kelly和jack提供他们的整套公寓              0.000964              0.999036
# 18541              excelente              0.001094              0.998906
# 7125              blissfully              0.001312              0.998688
# 46241                  sores              0.001462              0.998538
# 17658           environement              0.001573              0.998427
# 22209                  glady              0.001634              0.998366
# 62525                   这四个字              0.001667              0.998333
# 64527                     뷰엌              0.001705              0.998295
# 53241                  vieux              0.001758              0.998242

# %%
tf_logr_word_probs.sort_values('above_5th_percentile', ascending = False).head(20)
# Out:
#             features  above_5th_percentile  below_5th_percentile
# 26404      interesse              1.000000          2.526511e-07
# 25060        hübsche              1.000000          4.624776e-07
# 11436   confortamble              0.999999          5.283523e-07
# 50997          tryna              0.999999          5.309277e-07
# 28127          knick              0.999999          7.076661e-07
# 56915            моя              0.999999          8.247944e-07
# 49005        taverns              0.999999          9.835574e-07
# 8700            caos              0.999999          1.019216e-06
# 49636         thnaks              0.999999          1.117482e-06
# 37128      permitían              0.999999          1.119213e-06
# 63756          대응해줘서              0.999999          1.256359e-06
# 21137            fué              0.999999          1.369400e-06
# 41569        remédié              0.999998          1.587852e-06
# 23557       hausband              0.999998          1.593389e-06
# 25362  immédiatement              0.999998          1.819895e-06
# 41530        remnant              0.999998          1.901195e-06
# 15780          drauf              0.999998          2.101911e-06
# 5385           avons              0.999998          2.118431e-06
# 39508      prévenant              0.999998          2.139246e-06
# 19188        fallout              0.999998          2.232113e-06

# %%
pd.set_option('display.max_colwidth', 400)
df[['avg_rating', 'avg_score_below_5th_percentile', 'comments_clean']] [df['comments_clean'].str.contains('toffee')].sort_values('avg_rating')
# Out:
#         avg_rating  avg_score_below_5th_percentile  \
# 216616    4.901429                               0
#
#                                                                                                                                                                                                                                                                                                                                                                                                          comments_clean
# 216616  we enjoyed our visit to dc and our stat at teri and eddie s place it was exactly how it s pictured in the listing perfect landing spot after exploring the city it had everything we needed it was close to public transit so we never missed having a car solid state books was a great bookstore right down the street and the fancy radish was a delicious dinner spot get the rutabaga fondue and sticky...

# %%
df[['avg_rating', 'avg_score_below_5th_percentile', 'comments_clean']] [df['comments_clean'].str.contains('gratuitous')].sort_values('avg_rating')
# Out:
#         avg_rating  avg_score_below_5th_percentile  \
# 316883    3.591429                               1
# 278414    4.837143                               0
#
#                                                                                                                                                                                                                                                                                                                                                                                                          comments_clean
# 316883  we have been using airbnb for years and have had wonderful experiences all around the world this rental is by far the worst experience we have ever had with a house the house was dirty beds were not made there was trash in bathrooms and in the kitchen there were wet towels on the floors in all the restrooms we were very disappointed that we were never able to get in contact with the owner to g...
# 278414                                                            the brownstone is beautiful very well thought out and gives a very homely vibe the back patio is a nestled escape to unwind being a smart home is an added bonus and location is extremely convenient to reach anywhere in the city br codie is a gratuitous and communicative host who will make sure you have a wonderful time and want for nothing

# %%
df[['avg_rating', 'avg_score_below_5th_percentile', 'comments_clean']] [df['comments_clean'].str.contains('smoky')].sort_values('avg_rating')
# Out:
#         avg_rating  avg_score_below_5th_percentile  \
# 78664     4.751429                               0
# 317161    4.892857                               0
# 244181    4.925714                               0
# 205425    4.962857                               0
#
#                                                                                                                                                                                                                                                                                                                                                                                                          comments_clean
# 78664   karl s place has potential but it was the little things that made me cancel and leave there was still a smoky unpleasant smell as you enter the tv remote was broken and did not work easily there is no thermostat in the apartment so a guest cannot easily adjust the temperature i knew the bathroom would be small from the reviews but the only mirror was above the toilet which made the little sink...
# 317161                                                                                           had a lovely stay here while in town for a conference easy checkin clean space and quick communication br like a few others i also noticed the smoky smell and i did not use the fireplace at all it came back each day it was warm enough that opening the windows to air things out for a little while did the trick
# 244181  the place is as clean and bright as the photos i appreciate the space the full sized fridge toaster and microwave my first time using an induction top it does get a little smoky depending on what is being cooked so keeping the door open to avoid a fire department visit would be my suggestion the only window is in the bedroom br finally being in the basement we realize anne and sid have a very ...
# 205425                               what a beautiful hidden gem super clean comfortable and accommodating what a beautiful space in a quiet neighborhood great snacks and beverages options star has truly made a wonderful spot to stay even though it s 420 friendly the space isn t smoky at all i do not smoke just my boyfriend who stayed as well so even if you don t partake this is a wonderful place to stay

# %% [markdown]
# #### Lots of the words that show up as being strong predictors don't show up frequently in the corpus. So will run a GridSearch with min_df to try to improve this

# %%
pipe = Pipeline([
    ('tf', TfidfVectorizer() ),
    ('logr', LogisticRegression(class_weight = 'balanced') )
])

# %%
pipe_params = {
    'tf__stop_words' : ['english'],
    'tf__max_features' : [5_000, 10_000, 30_000],
    'tf__min_df' : [10, 25, 50, 100],  # Increase the minimum on the DF since I'm oversampling the minority class
    'tf__ngram_range': [ (1,1), (1,2), (1,3) ]
}

# %%
gs = GridSearchCV(pipe, pipe_params, n_jobs = -1, verbose = 10)

# %%
gs.fit(X_train_over['comments_clean'], y_train_over)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(estimator=Pipeline(steps=[('tf', TfidfVectorizer()),
#                                        ('logr',
#                                         LogisticRegression(class_weight='balanced'))]),
#              n_jobs=-1,
#              param_grid={'tf__max_features': [5000, 10000, 30000],
#                          'tf__min_df': [10, 25, 50, 100],
#                          'tf__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'tf__stop_words': ['english']},
#              verbose=10)

# %% [markdown]
# #### Best Params: 30k Max Features, Min DF 100, ngram_range: 1,2

# %%
gs.best_params_
# Out:
# {'tf__max_features': 30000,
#  'tf__min_df': 100,
#  'tf__ngram_range': (1, 2),
#  'tf__stop_words': 'english'}

# %% [markdown]
# #### Best Score: 0.9695174162440768

# %%
gs.best_score_
# Out:
# 0.9695174162440768

# %%
X_test
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                          comments_clean
# 26972                                                                                                                                                           hands down one of the best experiences this place is just as good as you see in the pictures if not better our host was very friendly and full of great information that allowed us to navigate and explore the neighborhood 10 10 would deff recommend
# 58773                                                                                                                                                                                                                                                                                      linden was very welcoming and ensured my stay was smooth and easy i really appreciated all thought that was put into my stay
# 135419  this place is amazing i would definitely recommend it john was really helpful in helping me get from dca to his place providing clear and thourough instructions when i got there i was struck by how nice the neighborhood was it was close to everything in the heart of georgetown shops restaurants etc nice area to walk and jog and get dinner the bed was soft as a cloud and the television was hd a...
# 203585  staying here was great very accommodating and i stayed for 5 months br kelvin and nakita are great host honestly the best br the location is great if you want to be near everything in the dc area the highway interstate is less than 5 mins away br we enjoyed being close to the suite way the nationals baseball park and more br you won t regret staying here if you need a something accommodating t...
# 55662                                                                                                                                                                                                                                                                              we greatly enjoyed our stay at home sweet city s place there was plenty of room the place was very clean and communication was great
# ...                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 124680                                                                                                                                                                                                                                                                 beautiful place to stay in dupont circle area very close to the metro station super cozy place comfy and simply awesome thank you for everything
# 276778                                                                                                                                                                                                                                                                                                                      beautiful home with all the necessary amenities in a great location we didn t want to leave
# 270842  wonderful place to stay in dc especially for a family vacation very comfortable space for six people privacy for everyone with four bedrooms and four bathrooms outside deck is a nice place to unwind after long day at museums and monuments great food across the street and other places within walking distance large safeway grocery store is only a two block walk away however the highlight is defi...
# 11349                                                                                                                                                                                                                                                                                                                                                                                      i enjoyed my stay at tommy s
# 224227                                                                                                                                                                                                                                                                                                                                                      thanks for cooperating with airbnb and facilitate my refund
#
# [80702 rows x 1 columns]

# %%
gs.score(X_train_over['comments_clean'], y_train_over), gs.score(X_test['comments_clean'], y_test)
# Out:
# (0.9729196109402278, 0.9422938712795222)

# %%
X_test.shape, y_test.shape
# Out:
# ((80702, 1), (80702,))

# %%
ConfusionMatrixDisplay.from_estimator(gs, X_test['comments_clean'], y_test);

# %% [markdown]
# ##### Recall score of 0.23 - still lots of false positives

# %%
recall_score(y_test, gs.predict(X_test['comments_clean']) )
# Out:
# 0.2263779527559055

# %%
prob_df = pd.DataFrame(gs.predict_proba(gs.best_estimator_.named_steps.tf.get_feature_names_out() ), columns = ['above_5th_percentile', 'below_5th_percentile'])
prob_df
# Out:
#        above_5th_percentile  below_5th_percentile
# 0                  0.709277              0.290723
# 1                  0.458382              0.541618
# 2                  0.247984              0.752016
# 3                  0.301339              0.698661
# 4                  0.190339              0.809661
# ...                     ...                   ...
# 29995              0.222040              0.777960
# 29996              0.544696              0.455304
# 29997              0.320738              0.679262
# 29998              0.170665              0.829335
# 29999              0.108137              0.891863
#
# [30000 rows x 2 columns]

# %%
feature_words = pd.DataFrame( gs.best_estimator_.named_steps.tf.get_feature_names_out(), columns = ['features'])
feature_words
# Out:
#          features
# 0              00
# 1           00 pm
# 2             000
# 3          000 br
# 4             02h
# ...           ...
# 29995  호스트는 친절하였다
# 29996         화장실
# 29997     화장실 욕실이
# 29998          환불
# 29999       환불 절대
#
# [30000 rows x 1 columns]

# %%
word_probs = feature_words.join(prob_df)
word_probs.sort_values('above_5th_percentile', ascending = False).head(20)
# Out:
#                     features  above_5th_percentile  below_5th_percentile
# 5661             comfortable              0.998442              0.001558
# 16122             loved stay              0.998424              0.001576
# 25313           stay perfect              0.997402              0.002598
# 15688       location perfect              0.996962              0.003038
# 16149           lovely place              0.996481              0.003519
# 1423   apartment comfortable              0.996257              0.003743
# 20134          place perfect              0.995749              0.004251
# 1396               apartment              0.995659              0.004341
# 16130                 lovely              0.995611              0.004389
# 15600         location clean              0.995583              0.004417
# 29334     wonderful location              0.995581              0.004419
# 20012       place convenient              0.995425              0.004575
# 26022       super responsive              0.995396              0.004604
# 19980        place beautiful              0.995353              0.004647
# 24629            space great              0.995316              0.004684
# 25996            super clean              0.995174              0.004826
# 5667   comfortable apartment              0.995148              0.004852
# 15601         location close              0.995126              0.004874
# 1184        amazing location              0.995054              0.004946
# 22341             responsive              0.994935              0.005065

# %%
word_probs.sort_values('below_5th_percentile', ascending = False).head(20)
# Out:
#                 features  above_5th_percentile  below_5th_percentile
# 13932            jasmine          2.346225e-08              1.000000
# 13939      jasmine great          3.183957e-06              0.999997
# 13947      jasmine place          8.367923e-06              0.999992
# 29657            yousong          1.091105e-05              0.999989
# 13943     jasmine humble          1.361038e-05              0.999986
# 7303                 dee          1.537471e-05              0.999985
# 13938       jasmine good          1.945562e-05              0.999981
# 13946       jasmine nice          3.293841e-05              0.999967
# 12793       host jasmine          4.431628e-05              0.999956
# 29666     yousong sharon          4.491381e-05              0.999955
# 13942      jasmine house          5.220165e-05              0.999948
# 17306         ms jasmine          5.615175e-05              0.999944
# 13954       jasmine wasn          6.019427e-05              0.999940
# 6122           concierge          6.716690e-05              0.999933
# 6212     conocer jasmine          6.973071e-05              0.999930
# 26751       time jasmine          7.412002e-05              0.999926
# 7307           dee place          7.425652e-05              0.999926
# 3372     booking jasmine          7.638830e-05              0.999924
...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...     5061  ...
# 3  https://a0.muscache.com/pictures/86072003/6709...     5803  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...     6527  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.84                   3.91                4.64
# 1                        4.91                   4.58                4.75
# 2                        4.98                   4.96                4.95
# 3                        4.93                   4.51                4.83
# 4                        4.82                   4.91                4.44
#
#                             license instant_bookable  \
# 0                               NaN                f
# 1  Hosted License: 5007242201001033                f
# 2  Hosted License: 5007242201000749                f
# 3                            Exempt                f
# 4                               NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           0
# 1                              5                                           0
# 2                              2                                           0
# 3                              2                                           0
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            5
# 2                                            2
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.52
# 1                                           0              2.75
# 2                                           0              0.33
# 3                                           0              0.57
# 4                                           0              0.54
#
# [5 rows x 75 columns]

# %%
pd.set_option('display.max_columns', 80)
listings[listings['id'] == 702842898980509221]
# Out:
#                       id                                      listing_url  \
# 2861  702842898980509221  https://www.airbnb.com/rooms/702842898980509221
#
#            scrape_id last_scraped       source  \
# 2861  20240323200252   2024-03-24  city scrape
#
#                                                    name  \
# 2861  Residential Neighborhood Suitable for Quiet Stays
#
#                                             description  \
# 2861  Set in the Northeast corner of DC, this home i...
#
#                                   neighborhood_overview  \
# 2861  One of the oldest neighborhoods in Washington,...
#
#                                             picture_url  host_id  \
# 2861  https://a0.muscache.com/pictures/miso/Hosting-...  6688891
#
#                                        host_url host_name  host_since  \
# 2861  https://www.airbnb.com/users/show/6688891   Jasmine  2013-06-01
#
#        host_location                                         host_about  \
# 2861  Washington, DC  I’m a DMV native. I travel often and rent my o...
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 2861     within an hour                88%                  90%
#
#      host_is_superhost                                 host_thumbnail_url  \
# 2861                 f  https://a0.muscache.com/im/pictures/user/12076...
#
#                                        host_picture_url host_neighbourhood  \
# 2861  https://a0.muscache.com/im/pictures/user/12076...           Deanwood
#
#       host_listings_count  host_total_listings_count  \
# 2861                    3                          4
#
#                     host_verifications host_has_profile_pic  \
# 2861  ['email', 'phone', 'work_email']                    t
#
#      host_identity_verified                                    neighbourhood  \
# 2861                      t  Washington, District of Columbia, United States
#
#                                  neighbourhood_cleansed  \
# 2861  Deanwood, Burrville, Grant Park, Lincoln Heigh...
#
#       neighbourhood_group_cleansed  latitude  longitude property_type  \
# 2861                           NaN  38.90095  -76.92674   Entire home
#
#             room_type  accommodates  bathrooms bathrooms_text  bedrooms  beds  \
# 2861  Entire home/apt             6        2.0        2 baths       3.0   6.0
#
#                                               amenities    price  \
# 2861  ["Microwave", "Dining table", "Hair dryer", "B...  $145.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# 2861               3              60                       3
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 2861                       3                    1125                    1125
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 2861                     3.0                  1125.0               NaN
#
#      has_availability  availability_30  availability_60  availability_90  \
# 2861                t               14               38               68
#
#       availability_365 calendar_last_scraped  number_of_reviews  \
# 2861               328            2024-03-24                 30
#
#       number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 2861                     16                       0   2022-09-23  2024-01-05
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 2861                   4.3                    4.43                       4.37
#
#       review_scores_checkin  review_scores_communication  \
# 2861                    4.6                         4.37
#
#       review_scores_location  review_scores_value  \
# 2861                     4.1                  4.3
#
#                                                 license instant_bookable  \
# 2861  Hosted License: 5007242201001640<br />Unhosted...                f
#
#       calculated_host_listings_count  \
# 2861                               2
#
#       calculated_host_listings_count_entire_homes  \
# 2861                                            2
#
#       calculated_host_listings_count_private_rooms  \
# 2861                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 2861                                            0               1.64
